# %% [markdown]
# # NDL Core Client Demo
#
# This notebook demonstrates how to use the NDL Core Client library to search and download datasets from the NDL Core Corpus.

# %% [markdown]
# ## Installation
#
# First, install the NDL Core Client library from GitHub:

# %%
# !pip install git+https://github.com/theodi/ndl-core-client.git

# %% [markdown]
# ## Usage
#
# Import the client and create an instance:

# %%
from ndl_core_client import NDLCoreClient

client = NDLCoreClient()

# %% [markdown]
# ## Search the NDL Core Corpus
#
# Use the `search` method to query the corpus. Results are returned as a pandas DataFrame:

# %%
results = client.search("Police use of force")
results
# Out:
#                              identifier  \
# 0  914b215d-b329-4443-8459-fc78dcbaa62b
# 1  e06b5cf8-3e2f-4bc6-a6e9-0530b5bd165d
# 2  2d165018-86c7-496b-a51a-408f76b536f4
# 3  77f7fc89-8e28-4c3f-878f-eaf84234ee56
# 4  b43709fd-b469-42c7-86cf-86b3f8546d13
#
#                                                title  \
# 0                                Police use of force
# 1  Rule change to support police facing dangerous...
# 2                     Police use of force statistics
# 3  Police use of force statistics, April 2024 to ...
# 4            wrans/answers2025-11-05 conversation_37
#
#                                          description                 source  \
# 0  Statistics on incidents where police officers ...            data.gov.uk
# 1  The legal test for the use of force in police ...                 gov.uk
# 2  Official statistics on police use of force inc...                 gov.uk
# 3  Statistics on incidents where police officers ...                 gov.uk
# ...
